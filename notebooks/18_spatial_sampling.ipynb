# %% [markdown]
# # 18 - Spatial Sampling
#
# **Purpose**: Geographic stratification techniques.
#
# This notebook demonstrates key functionality with synthetic data.

# %% [markdown]
# ## Installation (Kaggle/Colab)
#
# Run this cell to install the library if running on Kaggle or Google Colab.

# %%
# Uncomment the following line to install ununennium
# !pip install -q ununennium

# %% [markdown]
# ## Prerequisites and Environment Check

# %%
import sys
import torch
import numpy as np

print(f'Python: {sys.version}')
print(f'PyTorch: {torch.__version__}')
print(f'CUDA: {torch.cuda.is_available()}')
# Out:
# Python: 3.12.10 (tags/v3.12.10:0cc8128, Apr  8 2025, 12:21:36) [MSC v.1943 64 bit (AMD64)]
# PyTorch: 2.9.1+cpu
# CUDA: False

# %% [markdown]
# ## Reproducibility

# %%
SEED = 42
torch.manual_seed(SEED)
np.random.seed(SEED)

# %% [markdown]
# ## Core Workflow

# %%
import torch
import numpy as np

# %%
# Spatial stratification
n_samples = 100
coords = torch.rand(n_samples, 2)  # Normalized lat/lon
print(f'Sampled {n_samples} spatial locations')
# Out:
# Sampled 100 spatial locations

# %% [markdown]
# ## Validation

# %%
# All cells executed successfully
print('Notebook validation passed')
# Out:
# Notebook validation passed

# %% [markdown]
# ## Save Outputs

# %%
from pathlib import Path

ARTIFACT_DIR = Path('artifacts/notebooks/18')
ARTIFACT_DIR.mkdir(parents=True, exist_ok=True)
print(f'Artifacts directory: {ARTIFACT_DIR}')
# Out:
# Artifacts directory: artifacts\notebooks\18

# %% [markdown]
# ## Next Steps
#
# See the [notebooks README](README.md) for related tutorials.

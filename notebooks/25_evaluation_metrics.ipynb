# %% [markdown]
# # 25 - Evaluation Metrics
#
# **Purpose**: IoU, mAP, calibration metrics.
#
# This notebook demonstrates key functionality with synthetic data.

# %% [markdown]
# ## Installation (Kaggle/Colab)
#
# Run this cell to install the library if running on Kaggle or Google Colab.

# %%
# Uncomment the following line to install ununennium
# !pip install -q ununennium

# %% [markdown]
# ## Prerequisites and Environment Check

# %%
import sys
import torch
import numpy as np

print(f'Python: {sys.version}')
print(f'PyTorch: {torch.__version__}')
print(f'CUDA: {torch.cuda.is_available()}')
# Out:
# Python: 3.12.10 (tags/v3.12.10:0cc8128, Apr  8 2025, 12:21:36) [MSC v.1943 64 bit (AMD64)]
# PyTorch: 2.9.1+cpu
# CUDA: False

# %% [markdown]
# ## Reproducibility

# %%
SEED = 42
torch.manual_seed(SEED)
np.random.seed(SEED)

# %% [markdown]
# ## Core Workflow

# %%
import torch
from ununennium.metrics import iou_score, dice_score

# %%
pred = torch.randint(0, 5, (4, 128, 128))
target = torch.randint(0, 5, (4, 128, 128))
iou = iou_score(pred, target, num_classes=5)
print(f'IoU per class: {iou.tolist()}')
# Out:
# IoU per class: [0.1136402115225792, 0.10525865852832794, 0.11013159900903702, 0.11173558980226517, 0.11176019161939621]

# %% [markdown]
# ## Validation

# %%
# All cells executed successfully
print('Notebook validation passed')
# Out:
# Notebook validation passed

# %% [markdown]
# ## Save Outputs

# %%
from pathlib import Path

ARTIFACT_DIR = Path('artifacts/notebooks/25')
ARTIFACT_DIR.mkdir(parents=True, exist_ok=True)
print(f'Artifacts directory: {ARTIFACT_DIR}')
# Out:
# Artifacts directory: artifacts\notebooks\25

# %% [markdown]
# ## Next Steps
#
# See the [notebooks README](README.md) for related tutorials.
